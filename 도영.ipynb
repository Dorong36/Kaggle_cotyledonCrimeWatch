# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("train.csv")

# %%
data.iloc[:,64:80]
# Out:
#      GarageCond PavedDrive  WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  \
# 0            TA          Y         292           44              0        182
# 1            TA          Y           0          312             40          0
# 2            TA          Y         192           36              0          0
# 3            TA          Y           0          382              0          0
# 4            TA          Y           0           96            180          0
# ...         ...        ...         ...          ...            ...        ...
# 1746         TA          Y         276           99              0          0
# 1747         TA          Y         335            0              0          0
# 1748         TA          Y         200           54              0          0
# 1749         TA          Y         200          144              0          0
# 1750         TA          Y         375           26              0          0
#
# ...
