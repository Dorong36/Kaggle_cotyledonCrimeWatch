# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
train_data = pd.read_csv("train.csv")
test_data = pd.read_csv("test.csv")

# %%
mydata = train_data.iloc[:,64:80]

# %%
mydata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1751 entries, 0 to 1750
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   GarageCond     1651 non-null   object
#  1   PavedDrive     1751 non-null   object
#  2   WoodDeckSF     1751 non-null   int64
#  3   OpenPorchSF    1751 non-null   int64
#  4   EnclosedPorch  1751 non-null   int64
#  5   3SsnPorch      1751 non-null   int64
#  6   ScreenPorch    1751 non-null   int64
#  7   PoolArea       1751 non-null   int64
#  8   PoolQC         4 non-null      object
#  9   Fence          339 non-null    object
#  10  MiscFeature    63 non-null     object
#  11  MiscVal        1751 non-null   int64
#  12  MoSold         1751 non-null   int64
#  13  YrSold         1751 non-null   int64
#  14  SaleType       1751 non-null   object
#  15  SaleCondition  1751 non-null   object
# dtypes: int64(9), object(7)
# memory usage: 219.0+ KB

# %%
mydata.head()
# Out:
#   GarageCond PavedDrive  WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  \
# 0         TA          Y         292           44              0        182
# 1         TA          Y           0          312             40          0
# 2         TA          Y         192           36              0          0
# 3         TA          Y           0          382              0          0
# 4         TA          Y           0           96            180          0
#
#    ScreenPorch  PoolArea PoolQC  Fence MiscFeature  MiscVal  MoSold  YrSold  \
# 0            0         0    NaN    NaN         NaN        0      12    2009
# 1            0         0    NaN    NaN         NaN        0       3    2007
# 2            0         0    NaN    NaN         NaN        0       9    2008
# 3          110         0    NaN  GdPrv         NaN        0      11    2006
# 4            0         0    NaN  MnPrv         NaN        0       7    2006
#
#   SaleType SaleCondition
# 0       WD        Normal
# ...

# %%
mydata[1:50]
# Out:
#    GarageCond PavedDrive  WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  \
# 1          TA          Y           0          312             40          0
# 2          TA          Y         192           36              0          0
# 3          TA          Y           0          382              0          0
# 4          TA          Y           0           96            180          0
# 5          TA          Y          40            0              0          0
# 6          TA          Y           0           30              0          0
# 7          TA          Y          58            0              0          0
# 8          TA          Y           0            0              0          0
# 9          TA          Y           0            0              0          0
# 10         TA          Y           0            0              0          0
# 11         TA          Y           0            0              0        407
# ...
